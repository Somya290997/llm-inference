# %%
import torch
tensor = torch.load("layer_15.pt")
print(tensor['key'].shape)
print(tensor['value'].shape)

tensor['key'][0,0,0,0]
# Out:
# torch.Size([1, 16, 132, 128])
# torch.Size([1, 16, 132, 128])
# ...

# %%
batch_size = 1
n_heads = 16
sequence_len = 132  # variable len
dim_len = 128

device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"{device} \n")
layer_1 = torch.zeros([batch_size,n_heads,sequence_len,dim_len], dtype=torch.float32).to(device)
address_1 = hex(layer_1.data_ptr())

*address_1 = torch_2

# batch , n_head , squence_len , n_head;
# Out:
# mps

# %%
address_1
# Out:
# '0x10a514730'

# %%
address_1
